# %% [markdown]
# <font size=4 color='blue'>
#
# # <center> Clase 7, julio 7 del 2021 </center>

# %% [markdown]
# <font size=4 color='blue'>
#
# # <center> Topic that the Machine will learn: Mortality from diabetes </center>

# %% [markdown]
# <font size=4 color='blue'>
#
# ## Information about the topic

# %% [markdown]
# <font size=4>
#
# Evolution of diabetes after one year.
#
# In the present work, we characterize diabetes with the following ten features: age, sex, body mass index, mean blood pressure, and six measurements of blood serum (S1, S2, S3, S4, S5, S6).

# %% [markdown]
# <font size=4 color='blue'>
#
# ## Quantification of this information

# %% [markdown]
# <font size=4>
#
# Information is available on 442 patients (samples). The response of interest, Y, is a quantitative measure of disease progression one year after the start of the study. Y values vary between 25 and 346​.
#
# Information source: [diabetes data (samples)](https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html)
#
# Original paper: [Least-Angle-Regression_2004](./Literatura/Least-Angle-Regression_2004.pdf)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# Samples are available in the file diabetes.csv

df = pd.read_csv('diabetes.csv', sep ='\t')

# %%
# Showing the first 5 samples (features and target Y)

df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %% [markdown]
# <font size=4>
# Abreviation shave the following meaning:
#
#     AGE = Age
#     SEX = Sex
#     BMI = Body Mass Index (BMI)
#      BP = Mean Arterial Pressure (MAP)
#      S1 = Total Cholesterol (TC)
#      S2 = Low Density lipoproteins (LDL)
#      S3 = High Density lipoproteins (HDL)
#      S4 = Triglyceride (TG, TCH)
#      S5 = Serum Concentration of Lamorigine (LTG)
#      S6 = Glucose (GLU)
#      Y = Quantitative Measure of Diabetes Mellitus Disease Progression (QMDMDP) one year after the baseline.

# %%
# The describe() method generates a table with statistical information 
# for each of the features and the target.

df.describe()
# Out:
#               AGE         SEX         BMI          BP          S1          S2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.375792   94.647014  189.140271  115.439140
# std     13.109028    0.499561    4.418122   13.831283   34.608052   30.413081
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   42.200000  133.000000  301.000000  242.400000
#
#                S3          S4          S5          S6           Y
# count  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    49.788462    4.070249    4.641411   91.260181  152.133484
# std     12.934202    1.290450    0.522391   11.496335   77.093005
# min     22.000000    2.000000    3.258100   58.000000   25.000000
# 25%     40.250000    3.000000    4.276700   83.250000   87.000000
# 50%     48.000000    4.000000    4.620050   91.000000  140.500000
# 75%     57.750000    5.000000    4.997200   98.000000  211.500000
# max     99.000000    9.090000    6.107000  124.000000  346.000000

# %% [markdown]
# ## Histograms are created for each of the features that characterize patients with diabetes:

# %%
plt.figure(figsize=(20,8)) 

ax1 = plt.subplot(2,4,1)
ax2 = plt.subplot(2,4,2)
ax3 = plt.subplot(2,4,3)
ax4 = plt.subplot(2,4,4)

ax1.hist(df.AGE, bins=30, color='green',edgecolor='purple', alpha=0.5)
ax1.set_xlabel('Age (years)', size=15)
ax1.set_ylabel('Frequency', size=15)

ax2.hist(df.SEX, bins=30, color='orange',edgecolor='purple', alpha=0.5)
ax2.set_xlabel('Sex', size=15)

ax3.hist(df.BMI, bins=30, color='red',edgecolor='purple', alpha=0.5)
ax3.set_xlabel('Body_mass_index', size=15)

ax4.hist(df.BP, bins=30, color='blue',edgecolor='purple', alpha=0.5)
ax4.set_xlabel('Mean_Arterial_Pressure', size=15);

# %%
plt.figure(figsize=(20,8)) 

ax1 = plt.subplot(2,4,1)
ax2 = plt.subplot(2,4,2)
ax3 = plt.subplot(2,4,3)
ax4 = plt.subplot(2,4,4)

ax1.hist(df.S1, bins=30, color='green',edgecolor='purple', alpha=0.5)
ax1.set_xlabel('Total Cholesterol', size=15)
ax1.set_ylabel('Frequency', size=15)

ax2.hist(df.S2, bins=30, color='orange',edgecolor='purple', alpha=0.5)
ax2.set_xlabel('Low Density lipoproteins', size=15)

ax3.hist(df.S3, bins=30, color='red',edgecolor='purple', alpha=0.5)
ax3.set_xlabel('High Density lipoproteins', size=15)

ax4.hist(df.S4, bins=30, color='blue',edgecolor='purple', alpha=0.5)
ax4.set_xlabel('Triglyceride', size=15);

# %%
plt.figure(figsize=(15,8)) 

ax1 = plt.subplot(2,3,1)
ax2 = plt.subplot(2,3,2)
ax3 = plt.subplot(2,3,3)

ax1.hist(df.S5, bins=30, color='green',edgecolor='purple', alpha=0.5)
ax1.set_xlabel('Serum Concentration of Lamorigine', size=15)
ax1.set_ylabel('Frequency', size=15)

ax2.hist(df.S6, bins=30, color='orange',edgecolor='purple', alpha=0.5)
ax2.set_xlabel('Glucose', size=15)

ax3.hist(df.Y, bins=30, color='purple',edgecolor='black', alpha=0.5)
ax3.set_xlabel('Y(Diabetes Mellitus Disease Progression)', size=15)
# Out:
# Text(0.5, 0, 'Y(Diabetes Mellitus Disease Progression)')

# %% [markdown]
# <font size=4>
#
# To remove any possible correlation between the samples (the rows of the DataFrame), they are randomly reordered.

# %%
np.random.seed(1)

df = df.sample(frac=1)

# %% [markdown]
# <font size=4>
#
# The original samples are divided into 2 sets: 90% for learning and 10% for making inferences (predictions) after learning.

# %%
test_ratio = 0.1

learn_ratio = int((1.0-test_ratio)*len(df.values[:,:]))

df_learn = df.iloc[0:learn_ratio,:]
df_test  = df.iloc[learn_ratio:,:]

# %%
print(df_learn.shape)
print(df_test.shape)
# Out:
# (397, 11)
# (45, 11)

# %% [markdown]
# <font size=4>
#
# All variables must have the same order of magnitude in order to operate with the models.
# As a result, both the features (X) and the target (Y) values are normalized in the samples that will be utilized in learning:
#
# $$x_{i,norm} = \dfrac{x_{i}-\mu}{\sigma}$$
#
# $$y_{i,norm} = \dfrac{y_{i}-\mu}{\sigma}$$

# %%
mu = df_learn.mean()
sigma = df_learn.std()
df_learn_norm = (df_learn - mu)/ sigma
df_learn_norm.head()
# Out:
#           AGE       SEX       BMI        BP        S1        S2        S3  \
# 246  0.880549 -0.923573 -0.678927 -1.292722  1.678453  1.072260  1.179208
# 425 -1.627292 -0.923573 -0.858406 -1.702184 -2.097449 -2.351121  0.482966
# 293 -1.475302 -0.923573  1.923531  0.271467  0.439035  0.895527  0.018804
# 31  -0.487365 -0.923573 -1.374411 -1.702184 -0.800383 -1.113991  1.256568
# 359  0.804554  1.080025  0.106298  0.680929  0.150798  0.371874 -0.522717
#
#            S4        S5        S6         Y
# 246 -0.202277  0.963141 -1.241175 -0.960557
# 425 -1.597924 -0.422665 -1.065445  0.009443
# 293  0.014824 -1.148812 -0.011066  0.638633
# 31  -1.597924 -0.779650 -0.889715 -1.209611
# 359  0.728154  0.321844  1.306908  2.093633

# %% [markdown]
# <font size=5 color='blue'>
# Important note: The normalization of the test samples is carried out with the values ​​of $ \ mu $ and $ \ sigma $ obtained with the samples used for learning

# %%
df_test_norm = (df_test - mu) / sigma
df_test_norm.head()
# Out:
#           AGE       SEX       BMI        BP        S1        S2        S3  \
# 410 -0.183384  1.080025 -0.589187  0.175420  1.015508  0.784251 -0.600078
# 216  0.272587  1.080025  0.734477  1.042007  1.130803  1.556639 -1.451040
# 264  0.728558  1.080025  0.577432 -0.691166 -0.944502 -0.197598 -1.064239
# 209  0.804554  1.080025 -0.387272  1.403084 -1.059796 -0.341603 -1.605760
# 316  0.348582  1.080025  0.285778  0.030989  0.035503 -0.439788 -0.677438
#
#            S4        S5        S6         Y
# 410  0.728154  1.408068 -0.889715  0.756606
# 216  3.054233  0.974545  1.043313  1.267822
# 264 -0.047205 -1.253375 -0.450391 -0.082314
# 209  0.728154 -0.244655 -0.274661 -0.973665
# 316  0.728154  1.597094  0.867583  0.900795

# %% [markdown]
# <font size=4>
#
# Histograms of the variables to be used in the learning:

# %%
plt.figure(figsize=(20,8)) 

ax1 = plt.subplot(2,4,1)
ax2 = plt.subplot(2,4,2)
ax3 = plt.subplot(2,4,3)
ax4 = plt.subplot(2,4,4)

ax1.hist(df_learn_norm.AGE, bins=30, color='green',edgecolor='purple', alpha=0.5)
ax1.set_xlabel('x1(Age)', size=15)
ax1.set_ylabel('Frequency', size=15)

ax2.hist(df_learn_norm.SEX, bins=30, color='orange',edgecolor='purple', alpha=0.5)
ax2.set_xlabel('x2(Sex)', size=15)

ax3.hist(df_learn_norm.BMI, bins=30, color='red',edgecolor='purple', alpha=0.5)
ax3.set_xlabel('x3(Body_mass_index)', size=15)

ax4.hist(df_learn_norm.BP, bins=30, color='blue',edgecolor='purple', alpha=0.5)
ax4.set_xlabel('x4(Mean_Arterial_Pressure)', size=15);

# %%
plt.figure(figsize=(20,8)) 

ax1 = plt.subplot(2,4,1)
ax2 = plt.subplot(2,4,2)
ax3 = plt.subplot(2,4,3)
ax4 = plt.subplot(2,4,4)

ax1.hist(df_learn_norm.S1, bins=30, color='green',edgecolor='purple', alpha=0.5)
ax1.set_xlabel('x5(Total Cholesterol)', size=15)
ax1.set_ylabel('Frequency', size=15)

ax2.hist(df_learn_norm.S2, bins=30, color='orange',edgecolor='purple', alpha=0.5)
ax2.set_xlabel('x6(Low Density lipoproteins)', size=15)

ax3.hist(df_learn_norm.S3, bins=30, color='red',edgecolor='purple', alpha=0.5)
ax3.set_xlabel('x7(High Density lipoproteins)', size=15)

ax4.hist(df_learn_norm.S4, bins=30, color='blue',edgecolor='purple', alpha=0.5)
ax4.set_xlabel('x8(Triglyceride)', size=15);

# %%
plt.figure(figsize=(20,8)) 

ax1 = plt.subplot(2,3,1)
ax2 = plt.subplot(2,3,2)
ax3 = plt.subplot(2,3,3)

ax1.hist(df_learn_norm.S5, bins=30, color='green',edgecolor='purple', alpha=0.5)
ax1.set_xlabel('x9(Serum Concentration of Lamorigine)', size=15)
ax1.set_ylabel('Frequency', size=15)

ax2.hist(df_learn_norm.S6, bins=30, color='orange',edgecolor='purple', alpha=0.5)
ax2.set_xlabel('x10(Glucose)', size=15)

ax3.hist(df_learn_norm.Y, bins=30, color='purple',edgecolor='black', alpha=0.5)
ax3.set_xlabel('Y(Diabetes Mellitus Disease Progression)', size=15)
# Out:
# Text(0.5, 0, 'Y(Diabetes Mellitus Disease Progression)')

# %% [markdown]
# <font size=4>
# X and Y values are extracted from the columns of the DataFrame.

# %%
learn_x = df_learn_norm.values[:,:-1]
learn_y = df_learn_norm.values[:,-1:]

# %%
test_x = df_test_norm.values[:,:-1]
test_y = df_test_norm.values[:,-1:]

# %%
print(learn_x.shape)
print(learn_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (397, 10)
# (397, 1)
# (45, 10)
# (45, 1)

# %% [markdown]
# <font size=5 color='blue'>
#
# # <center> Modeling different Learning Machines </center>

# %% [markdown]
# <font size=4 color='blue'>
#
# # <center> Implemented using the Keras framework as frontend </center>
#
#
# <font size=4 color='mediumvioletred'>
#
# [Keras](https://keras.io/)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.layers import Activation
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras import initializers
from tensorflow.keras import optimizers

np.random.seed(1)

# %%
keras.__version__
# Out:
# '2.4.0'

# %% [markdown]
# <font size=4 color='black'>
#
# The features that determine the phenomen are described by the vector  $X = (x_1, x_2, x_3, ...x_k,...x_K)$
#
# The model assumes that the output Y varies linearly with each feature
#     $$ F(X) = \sum_{k=1}^K w_k*x_k + b$$

# %% [markdown]
# <font size=5 color='blue'>
#
# ## <center> The first Learning Machine</center>

# %% [markdown]
# <font size=5 color='blue'>
#
# Model of the Machine: the output $Y$ depends linearly on each of the features.

# %%
import networkx as nx

class Network(object):
    
    def  __init__ (self,sizes):
        self.num_layers = len(sizes)
        print("It has", self.num_layers, "layers,")
        self.sizes = sizes
        print("with the following number of nodes per layer",self.sizes)
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x)
                        for x, y in zip(sizes[:-1], sizes[1:])]
        
    def feedforward(self, x_of_sample):
        """Return the output of the network F(x_of_sample) """        
        for b, w in zip(self.biases, self.weights):
            x_of_sample = sigmoid(np.dot(w, x_of_sample)+b)
        return x_of_sample
    
    def graph(self,sizes):
        a=[]
        ps={}
        Q = nx.Graph()
        for i in range(len(sizes)):
            Qi=nx.Graph()    
            n=sizes[i]
            nodos=np.arange(n)
            Qi.add_nodes_from(nodos)
            l_i=Qi.nodes
            Q = nx.union(Q, Qi, rename = (None, 'Q%i-'%i))
            if len(l_i)==1:
                ps['Q%i-0'%i]=[i/(len(sizes)), 1/2]
            else:
                for j in range(len(l_i)+1):
                    ps['Q%i-%i'%(i,j)]=[i/(len(sizes)),(1/(len(l_i)*len(l_i)))+(j/(len(l_i)))]
            a.insert(i,Qi)
        for i in range(len(a)-1):
            for j in range(len(a[i])):
                for k in range(len(a[i+1])):
                    Q.add_edge('Q%i-%i' %(i,j),'Q%i-%i' %(i+1,k))            
        nx.draw(Q, pos = ps)

# %%
n_x = learn_x.shape[1] 
n_y = learn_y.shape[1]
    
layers = [n_x, n_y]
net = Network(layers)
net.graph(layers)
# Out:
# It has 2 layers,
# with the following number of nodes per layer [10, 1]

# %% [markdown]
# <font size=5 color='blue'>
#
# Definition of the architecture.
#
# It includes the initialization of weights and biases, as well as the activation functions.

# %%
np.random.seed(1)

input_nodes = n_x     # The input layer has n_x nodes
output_nodes = n_y    # The output layer has n_y nodes

model = Sequential()

# For the first layer, you need to indicate its input layer, which corresponds to
# the input layer of the network.

model.add(Dense(output_nodes,  kernel_initializer='uniform', bias_initializer='zeros', \
                input_dim=input_nodes, activation='linear'))

# %% [markdown]
# <font size=5 color='blue'>
# Architecture Summary and Chart

# %%
plot_model(model, to_file='model.png', show_shapes=True, rankdir='TB', 
      expand_nested=True, show_layer_names=True, dpi=96)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 11
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <font size=5  color='blue'>
#
# Compiling the model. Includes the optimizer definition

# %%
# We define the optimizing function and their hyperparameters: learining rate(lr), 
# decay, momentum and nesterov (whether to apply Nesterov gradient)

sgd = optimizers.SGD(lr=0.01, momentum=0.0, nesterov=False)

model.compile(loss='mean_squared_error', optimizer=sgd)

# %% [markdown]
# <font size=5 color='blue'>
#
# The Machine is learning

# %%
# 10 % of the learning samples will be used to validate the learning
validation_ratio = 0.1
epochs = 600

history = model.fit(learn_x, learn_y, epochs=epochs, validation_split = validation_ratio, verbose=1)

# the "history" object contains the information generated during the learning
# Out:
# Epoch 1/600
# 12/12 [==============================] - 0s 21ms/step - loss: 0.8742 - val_loss: 0.6716
# Epoch 2/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6682 - val_loss: 0.5721
# Epoch 3/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5626 - val_loss: 0.5379
# Epoch 4/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6121 - val_loss: 0.5101
# Epoch 5/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5082 - val_loss: 0.4893
# Epoch 6/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5047 - val_loss: 0.4769
# Epoch 7/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5212 - val_loss: 0.4627
# Epoch 8/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4642 - val_loss: 0.4660
# Epoch 9/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5111 - val_loss: 0.4622
# Epoch 10/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4911 - val_loss: 0.4615
# Epoch 11/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4814 - val_loss: 0.4625
# Epoch 12/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5089 - val_loss: 0.4608
# Epoch 13/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4866 - val_loss: 0.4630
# Epoch 14/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5244 - val_loss: 0.4578
# Epoch 15/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4587 - val_loss: 0.4549
# Epoch 16/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5013 - val_loss: 0.4470
# Epoch 17/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5106 - val_loss: 0.4461
# Epoch 18/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5081 - val_loss: 0.4492
# Epoch 19/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5172 - val_loss: 0.4459
# Epoch 20/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4644 - val_loss: 0.4435
# Epoch 21/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5021 - val_loss: 0.4481
# Epoch 22/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5489 - val_loss: 0.4472
# Epoch 23/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5301 - val_loss: 0.4474
# Epoch 24/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4773 - val_loss: 0.4572
# Epoch 25/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5302 - val_loss: 0.4545
# Epoch 26/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4922 - val_loss: 0.4517
# Epoch 27/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5202 - val_loss: 0.4512
# Epoch 28/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5124 - val_loss: 0.4540
# Epoch 29/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5196 - val_loss: 0.4481
# Epoch 30/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4928 - val_loss: 0.4402
# Epoch 31/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4874 - val_loss: 0.4439
# Epoch 32/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5153 - val_loss: 0.4465
# Epoch 33/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4790 - val_loss: 0.4462
# Epoch 34/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5211 - val_loss: 0.4435
# Epoch 35/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4918 - val_loss: 0.4427
# Epoch 36/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5004 - val_loss: 0.4439
# Epoch 37/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4818 - val_loss: 0.4414
# Epoch 38/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5187 - val_loss: 0.4419
# Epoch 39/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5041 - val_loss: 0.4385
# Epoch 40/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4813 - val_loss: 0.4404
# Epoch 41/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5121 - val_loss: 0.4410
# Epoch 42/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5187 - val_loss: 0.4401
# Epoch 43/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5198 - val_loss: 0.4426
# Epoch 44/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5413 - val_loss: 0.4455
# Epoch 45/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5020 - val_loss: 0.4442
# Epoch 46/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4586 - val_loss: 0.4423
# Epoch 47/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5044 - val_loss: 0.4418
# Epoch 48/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5223 - val_loss: 0.4424
# Epoch 49/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5312 - val_loss: 0.4360
# Epoch 50/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5418 - val_loss: 0.4366
# Epoch 51/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5566 - val_loss: 0.4371
# Epoch 52/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5334 - val_loss: 0.4375
# Epoch 53/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5104 - val_loss: 0.4356
# Epoch 54/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4992 - val_loss: 0.4365
# Epoch 55/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5445 - val_loss: 0.4358
# Epoch 56/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5414 - val_loss: 0.4426
# Epoch 57/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4957 - val_loss: 0.4380
# Epoch 58/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4907 - val_loss: 0.4435
# Epoch 59/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5432 - val_loss: 0.4354
# Epoch 60/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5473 - val_loss: 0.4366
# Epoch 61/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4942 - val_loss: 0.4417
# Epoch 62/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5396 - val_loss: 0.4418
# Epoch 63/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4623 - val_loss: 0.4406
# Epoch 64/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5663 - val_loss: 0.4464
# Epoch 65/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5580 - val_loss: 0.4411
# Epoch 66/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4856 - val_loss: 0.4481
# Epoch 67/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5213 - val_loss: 0.4500
# Epoch 68/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5263 - val_loss: 0.4448
# Epoch 69/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4544 - val_loss: 0.4454
# Epoch 70/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4954 - val_loss: 0.4510
# Epoch 71/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5062 - val_loss: 0.4501
# Epoch 72/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5429 - val_loss: 0.4502
# Epoch 73/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5088 - val_loss: 0.4470
# Epoch 74/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5469 - val_loss: 0.4404
# Epoch 75/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5321 - val_loss: 0.4393
# Epoch 76/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5011 - val_loss: 0.4363
# Epoch 77/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5561 - val_loss: 0.4390
# Epoch 78/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5149 - val_loss: 0.4420
# Epoch 79/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4745 - val_loss: 0.4450
# Epoch 80/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5113 - val_loss: 0.4457
# Epoch 81/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4896 - val_loss: 0.4448
# Epoch 82/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4942 - val_loss: 0.4481
# Epoch 83/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5118 - val_loss: 0.4493
# Epoch 84/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5334 - val_loss: 0.4485
# Epoch 85/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4834 - val_loss: 0.4483
# Epoch 86/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4920 - val_loss: 0.4464
# Epoch 87/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5538 - val_loss: 0.4517
# Epoch 88/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5498 - val_loss: 0.4464
# Epoch 89/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5215 - val_loss: 0.4437
# Epoch 90/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4928 - val_loss: 0.4464
# Epoch 91/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4801 - val_loss: 0.4549
# Epoch 92/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5389 - val_loss: 0.4438
# Epoch 93/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5389 - val_loss: 0.4470
# Epoch 94/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5139 - val_loss: 0.4471
# Epoch 95/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5291 - val_loss: 0.4465
# Epoch 96/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4871 - val_loss: 0.4505
# Epoch 97/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5033 - val_loss: 0.4494
# Epoch 98/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5228 - val_loss: 0.4425
# Epoch 99/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4775 - val_loss: 0.4468
# Epoch 100/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4903 - val_loss: 0.4474
# Epoch 101/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5100 - val_loss: 0.4360
# Epoch 102/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4938 - val_loss: 0.4345
# Epoch 103/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5149 - val_loss: 0.4333
# Epoch 104/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5034 - val_loss: 0.4392
# Epoch 105/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5162 - val_loss: 0.4419
# Epoch 106/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5145 - val_loss: 0.4452
# Epoch 107/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5137 - val_loss: 0.4429
# Epoch 108/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.
600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5137 - val_loss: 0.4536
# Epoch 240/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5480 - val_loss: 0.4541
# Epoch 241/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5145 - val_loss: 0.4533
# Epoch 242/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5125 - val_loss: 0.4535
# Epoch 243/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4957 - val_loss: 0.4530
# Epoch 244/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5268 - val_loss: 0.4621
# Epoch 245/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5206 - val_loss: 0.4584
# Epoch 246/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5254 - val_loss: 0.4523
# Epoch 247/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5073 - val_loss: 0.4475
# Epoch 248/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4663 - val_loss: 0.4426
# Epoch 249/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4772 - val_loss: 0.4502
# Epoch 250/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4922 - val_loss: 0.4562
# Epoch 251/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5164 - val_loss: 0.4632
# Epoch 252/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5060 - val_loss: 0.4612
# Epoch 253/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4837 - val_loss: 0.4665
# Epoch 254/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4931 - val_loss: 0.4602
# Epoch 255/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5066 - val_loss: 0.4623
# Epoch 256/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5508 - val_loss: 0.4582
# Epoch 257/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5048 - val_loss: 0.4499
# Epoch 258/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5044 - val_loss: 0.4485
# Epoch 259/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4829 - val_loss: 0.4459
# Epoch 260/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5331 - val_loss: 0.4388
# Epoch 261/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5022 - val_loss: 0.4404
# Epoch 262/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5225 - val_loss: 0.4424
# Epoch 263/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5096 - val_loss: 0.4527
# Epoch 264/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5140 - val_loss: 0.4485
# Epoch 265/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4953 - val_loss: 0.4495
# Epoch 266/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4907 - val_loss: 0.4547
# Epoch 267/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4978 - val_loss: 0.4534
# Epoch 268/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5183 - val_loss: 0.4544
# Epoch 269/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5463 - val_loss: 0.4599
# Epoch 270/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5060 - val_loss: 0.4553
# Epoch 271/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4907 - val_loss: 0.4536
# Epoch 272/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5006 - val_loss: 0.4523
# Epoch 273/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5045 - val_loss: 0.4506
# Epoch 274/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5034 - val_loss: 0.4466
# Epoch 275/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5279 - val_loss: 0.4404
# Epoch 276/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5341 - val_loss: 0.4470
# Epoch 277/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5268 - val_loss: 0.4484
# Epoch 278/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4717 - val_loss: 0.4467
# Epoch 279/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4629 - val_loss: 0.4469
# Epoch 280/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5289 - val_loss: 0.4451
# Epoch 281/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4827 - val_loss: 0.4509
# Epoch 282/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5334 - val_loss: 0.4519
# Epoch 283/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4990 - val_loss: 0.4558
# Epoch 284/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5426 - val_loss: 0.4588
# Epoch 285/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5044 - val_loss: 0.4551
# Epoch 286/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5065 - val_loss: 0.4510
# Epoch 287/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5149 - val_loss: 0.4533
# Epoch 288/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4770 - val_loss: 0.4540
# Epoch 289/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5295 - val_loss: 0.4507
# Epoch 290/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5463 - val_loss: 0.4470
# Epoch 291/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4853 - val_loss: 0.4433
# Epoch 292/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4675 - val_loss: 0.4422
# Epoch 293/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4728 - val_loss: 0.4539
# Epoch 294/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5066 - val_loss: 0.4560
# Epoch 295/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4879 - val_loss: 0.4490
# Epoch 296/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5352 - val_loss: 0.4470
# Epoch 297/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5004 - val_loss: 0.4512
# Epoch 298/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4746 - val_loss: 0.4411
# Epoch 299/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5093 - val_loss: 0.4452
# Epoch 300/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5463 - val_loss: 0.4501
# Epoch 301/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4968 - val_loss: 0.4386
# Epoch 302/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5025 - val_loss: 0.4470
# Epoch 303/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4668 - val_loss: 0.4447
# Epoch 304/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.
600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4791 - val_loss: 0.4450
# Epoch 435/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5285 - val_loss: 0.4446
# Epoch 436/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4592 - val_loss: 0.4506
# Epoch 437/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4899 - val_loss: 0.4489
# Epoch 438/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4961 - val_loss: 0.4468
# Epoch 439/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5118 - val_loss: 0.4413
# Epoch 440/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5385 - val_loss: 0.4442
# Epoch 441/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5370 - val_loss: 0.4455
# Epoch 442/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4800 - val_loss: 0.4439
# Epoch 443/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4908 - val_loss: 0.4443
# Epoch 444/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5112 - val_loss: 0.4412
# Epoch 445/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5158 - val_loss: 0.4410
# Epoch 446/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5486 - val_loss: 0.4441
# Epoch 447/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5375 - val_loss: 0.4463
# Epoch 448/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4649 - val_loss: 0.4474
# Epoch 449/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4982 - val_loss: 0.4455
# Epoch 450/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5044 - val_loss: 0.4522
# Epoch 451/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4889 - val_loss: 0.4512
# Epoch 452/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5228 - val_loss: 0.4522
# Epoch 453/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5333 - val_loss: 0.4455
# Epoch 454/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4686 - val_loss: 0.4438
# Epoch 455/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4691 - val_loss: 0.4458
# Epoch 456/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4812 - val_loss: 0.4570
# Epoch 457/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4600 - val_loss: 0.4540
# Epoch 458/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4694 - val_loss: 0.4558
# Epoch 459/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4798 - val_loss: 0.4485
# Epoch 460/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5206 - val_loss: 0.4446
# Epoch 461/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4678 - val_loss: 0.4392
# Epoch 462/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5490 - val_loss: 0.4417
# Epoch 463/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5080 - val_loss: 0.4430
# Epoch 464/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5415 - val_loss: 0.4423
# Epoch 465/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5078 - val_loss: 0.4474
# Epoch 466/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5000 - val_loss: 0.4388
# Epoch 467/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4983 - val_loss: 0.4410
# Epoch 468/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5130 - val_loss: 0.4428
# Epoch 469/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4774 - val_loss: 0.4540
# Epoch 470/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5078 - val_loss: 0.4557
# Epoch 471/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4778 - val_loss: 0.4516
# Epoch 472/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5010 - val_loss: 0.4481
# Epoch 473/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5019 - val_loss: 0.4546
# Epoch 474/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4841 - val_loss: 0.4500
# Epoch 475/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4918 - val_loss: 0.4445
# Epoch 476/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5171 - val_loss: 0.4503
# Epoch 477/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5530 - val_loss: 0.4429
# Epoch 478/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4930 - val_loss: 0.4419
# Epoch 479/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4938 - val_loss: 0.4417
# Epoch 480/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4580 - val_loss: 0.4415
# Epoch 481/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5144 - val_loss: 0.4487
# Epoch 482/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5071 - val_loss: 0.4470
# Epoch 483/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5605 - val_loss: 0.4515
# Epoch 484/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5033 - val_loss: 0.4555
# Epoch 485/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5240 - val_loss: 0.4461
# Epoch 486/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5083 - val_loss: 0.4464
# Epoch 487/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5097 - val_loss: 0.4491
# Epoch 488/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4966 - val_loss: 0.4527
# Epoch 489/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5031 - val_loss: 0.4536
# Epoch 490/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4848 - val_loss: 0.4506
# Epoch 491/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5264 - val_loss: 0.4505
# Epoch 492/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4968 - val_loss: 0.4486
# Epoch 493/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5041 - val_loss: 0.4567
# Epoch 494/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5361 - val_loss: 0.4505
# Epoch 495/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4923 - val_loss: 0.4525
# Epoch 496/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4865 - val_loss: 0.4514
# Epoch 497/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4999 - val_loss: 0.4495
# Epoch 498/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5504 - val_loss: 0.4514
# Epoch 499/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4951 - val_loss: 0.4494
# Epoch 500/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5037 - val_loss: 0.4455
# Epoch 501/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5282 - val_loss: 0.4441
# Epoch 502/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4860 - val_loss: 0.4436
# Epoch 503/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5311 - val_loss: 0.4469
# Epoch 504/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5273 - val_loss: 0.4419
# Epoch 505/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5133 - val_loss: 0.4395
# Epoch 506/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4989 - val_loss: 0.4359
# Epoch 507/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5163 - val_loss: 0.4361
# Epoch 508/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5480 - val_loss: 0.4326
# Epoch 509/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5299 - val_loss: 0.4357
# Epoch 510/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5125 - val_loss: 0.4305
# Epoch 511/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5256 - val_loss: 0.4297
# Epoch 512/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5196 - val_loss: 0.4322
# Epoch 513/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4511 - val_loss: 0.4354
# Epoch 514/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5056 - val_loss: 0.4438
# Epoch 515/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4871 - val_loss: 0.4444
# Epoch 516/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4714 - val_loss: 0.4455
# Epoch 517/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4760 - val_loss: 0.4509
# Epoch 518/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5094 - val_loss: 0.4562
# Epoch 519/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4727 - val_loss: 0.4564
# Epoch 520/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5007 - val_loss: 0.4498
# Epoch 521/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5070 - val_loss: 0.4447
# Epoch 522/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4650 - val_loss: 0.4449
# Epoch 523/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5123 - val_loss: 0.4444
# Epoch 524/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4979 - val_loss: 0.4442
# Epoch 525/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4716 - val_loss: 0.4480
# Epoch 526/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5045 - val_loss: 0.4501
# Epoch 527/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5228 - val_loss: 0.4458
# Epoch 528/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5285 - val_loss: 0.4473
# Epoch 529/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4732 - val_loss: 0.4430
# Epoch 530/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4927 - val_loss: 0.4411
# Epoch 531/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5384 - val_loss: 0.4474
# Epoch 532/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4288 - val_loss: 0.4496
# Epoch 533/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5012 - val_loss: 0.4521
# Epoch 534/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4817 - val_loss: 0.4529
# Epoch 535/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5051 - val_loss: 0.4522
# Epoch 536/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4994 - val_loss: 0.4446
# Epoch 537/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5241 - val_loss: 0.4499
# Epoch 538/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4693 - val_loss: 0.4379
# Epoch 539/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4479 - val_loss: 0.4405
# Epoch 540/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4990 - val_loss: 0.4426
# Epoch 541/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4931 - val_loss: 0.4463
# Epoch 542/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4957 - val_loss: 0.4478
# Epoch 543/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5696 - val_loss: 0.4540
# Epoch 544/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5285 - val_loss: 0.4608
# Epoch 545/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4831 - val_loss: 0.4499
# Epoch 546/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4820 - val_loss: 0.4514
# Epoch 547/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5017 - val_loss: 0.4499
# Epoch 548/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5023 - val_loss: 0.4438
# Epoch 549/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4807 - val_loss: 0.4404
# Epoch 550/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4843 - val_loss: 0.4355
# Epoch 551/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4934 - val_loss: 0.4380
# Epoch 552/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4813 - val_loss: 0.4378
# Epoch 553/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5009 - val_loss: 0.4436
# Epoch 554/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5263 - val_loss: 0.4450
# Epoch 555/600
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5135 - val_loss: 0.4414
# Epoch 556/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5016 - val_loss: 0.4512
# Epoch 557/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5304 - val_loss: 0.4480
# Epoch 558/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4832 - val_loss: 0.4471
# Epoch 559/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4727 - val_loss: 0.4512
# Epoch 560/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5300 - val_loss: 0.4523
# Epoch 561/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5192 - val_loss: 0.4474
# Epoch 562/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4743 - val_loss: 0.4443
# Epoch 563/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4695 - val_loss: 0.4508
# Epoch 564/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4806 - val_loss: 0.4497
# Epoch 565/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5057 - val_loss: 0.4468
# Epoch 566/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5534 - val_loss: 0.4433
# Epoch 567/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5496 - val_loss: 0.4470
# Epoch 568/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5223 - val_loss: 0.4516
# Epoch 569/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5725 - val_loss: 0.4529
# Epoch 570/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4906 - val_loss: 0.4486
# Epoch 571/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4951 - val_loss: 0.4557
# Epoch 572/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5111 - val_loss: 0.4579
# Epoch 573/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4432 - val_loss: 0.4584
# Epoch 574/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4849 - val_loss: 0.4569
# Epoch 575/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5186 - val_loss: 0.4540
# Epoch 576/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5548 - val_loss: 0.4548
# Epoch 577/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4890 - val_loss: 0.4563
# Epoch 578/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5023 - val_loss: 0.4547
# Epoch 579/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4669 - val_loss: 0.4537
# Epoch 580/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5096 - val_loss: 0.4587
# Epoch 581/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5009 - val_loss: 0.4512
# Epoch 582/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5608 - val_loss: 0.4548
# Epoch 583/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5285 - val_loss: 0.4572
# Epoch 584/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4876 - val_loss: 0.4526
# Epoch 585/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4925 - val_loss: 0.4562
# Epoch 586/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5049 - val_loss: 0.4629
# Epoch 587/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5172 - val_loss: 0.4628
# Epoch 588/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4517 - val_loss: 0.4630
# Epoch 589/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5128 - val_loss: 0.4648
# Epoch 590/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5263 - val_loss: 0.4652
# Epoch 591/600
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4572 - val_loss: 0.4607
# Epoch 592/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5395 - val_loss: 0.4520
# Epoch 593/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5400 - val_loss: 0.4492
# Epoch 594/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4899 - val_loss: 0.4477
# Epoch 595/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5052 - val_loss: 0.4534
# Epoch 596/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5257 - val_loss: 0.4588
# Epoch 597/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4648 - val_loss: 0.4630
# Epoch 598/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4766 - val_loss: 0.4684
# Epoch 599/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5152 - val_loss: 0.4612
# Epoch 600/600
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4661 - val_loss: 0.4576

# %% [markdown]
# <font size=5 color='blue'>
#
# Plots of the cost function versus epoch

# %%
plt.figure(figsize=(10, 7))

plt.plot(history.history['loss'], color='red')
plt.plot(history.history['val_loss'], color='green')
plt.title('Cost function', size=16)
plt.ylabel('Cost', size=16)
plt.xlabel('Epoch', size=16)
plt.legend(['cost_train', 'cost_validation'], loc='upper right', prop={'size': 16})
plt.show()

# %% [markdown]
# <font size=5 color='blue'>
#
# Underfitting

# %% [markdown]
# <font size = 5 color = 'blue'>
#
# Evaluation of the Smart Machine.
#
# This is done using the test samples.

# %%
preds = model.evaluate(x=test_x, y=test_y)

print ("Loss = " + str(preds))
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5039
# Loss = 0.5039479732513428

# %% [markdown]
# <font size=5 color='blue'>
#
# ## <center> A new Learning Machine</center>

# %% [markdown]
# <font size=5 color='blue'>
#
# Model of the Machine: The output $Y$ does not depend linearly with the features.
# This fact is modeled with a sigmoid type function; for example, a hyperbolic tangent

# %% [markdown]
# <font size=4 color='black'>
#
# The features that determine the phenomen are described by the vector  $X = (x_1, x_2, x_3, ...x_k,...x_K)$
#
# The our model assumes that the output Y varies lienarly with each feature
#     $$ z = \sum_{k=1}^K w_k*x_k + b$$
#     $$ F(X) = tanh(z)= \frac{{e}^{2z} - 1}{{e}^{2z} + 1}$$

# %%
def tanh(z):
    return (np.exp(2*z)- 1)/(np.exp(2*z)+1)

# The following array is generated for plotting the hyperbolic tangent function
x1 = np.arange(-2, 2.0, 0.1)
y1 = 1.759*tanh((2/3*x1))

y2 = x1
#Samples and function F are plotted
plt.figure(figsize=(13,8))

plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('legend', fontsize=16)
plt.ylabel('Y', fontsize=16)
plt.xlabel('Z', fontsize=16)
plt.grid(True)
plt.title('Sigmoid-type = 1.7159*tanh((2/3*x)', size=20)

#Plotting function
plt.plot(x1, y1, color='green', lw=4)
plt.plot(x1, y2, color='red', lw=3)

plt.show()

# %%
n_x = learn_x.shape[1] 
n_y = learn_y.shape[1]
    
layers = [n_x, n_y]
net = Network(layers)
net.graph(layers)
# Out:
# It has 2 layers,
# with the following number of nodes per layer [10, 1]

# %% [markdown]
# <font size=5 color='blue'>
#
# Model architecture

# %%
np.random.seed(1)

input_nodes = n_x     # The input layer has n_x nodes
output_nodes = n_y    # The output layer has n_y nodes

model = Sequential()

model.add(Dense(output_nodes,  kernel_initializer='uniform', bias_initializer='zeros', \
                input_dim=input_nodes, activation='tanh'))

# %% [markdown]
# <font size=5 color='blue'>
# Architecture Summary and Chart

# %%
plot_model(model, to_file='model.png', show_shapes=True, rankdir='TB', 
      expand_nested=True, show_layer_names=True, dpi=96)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <font size=5  color='blue'>
#
# Compiling the model. Includes the optimizer definition

# %%
sgd = optimizers.SGD(lr=0.01)

model.compile(loss='mean_squared_error', optimizer=sgd)

# %% [markdown]
# <font size=5 color='blue'>
#
# The Machine is learning

# %%
# 10 % of the learning data will be used to validate the training
validation_fraction = 0.1
epochs = 600

history = model.fit(learn_x, learn_y, epochs=epochs, validation_split = validation_fraction, verbose=2)

# the "history" object contains information generated during learning
# Out:
# Epoch 1/600
# 12/12 - 0s - loss: 0.8489 - val_loss: 0.7028
# Epoch 2/600
# 12/12 - 0s - loss: 0.6647 - val_loss: 0.6185
# Epoch 3/600
# 12/12 - 0s - loss: 0.6141 - val_loss: 0.5805
# Epoch 4/600
# 12/12 - 0s - loss: 0.5861 - val_loss: 0.5564
# Epoch 5/600
# 12/12 - 0s - loss: 0.5713 - val_loss: 0.5444
# Epoch 6/600
# 12/12 - 0s - loss: 0.5610 - val_loss: 0.5351
# Epoch 7/600
# 12/12 - 0s - loss: 0.5550 - val_loss: 0.5293
# Epoch 8/600
# 12/12 - 0s - loss: 0.5487 - val_loss: 0.5241
# Epoch 9/600
# 12/12 - 0s - loss: 0.5431 - val_loss: 0.5215
# Epoch 10/600
# 12/12 - 0s - loss: 0.5402 - val_loss: 0.5131
# Epoch 11/600
# 12/12 - 0s - loss: 0.5374 - val_loss: 0.5134
# Epoch 12/600
# 12/12 - 0s - loss: 0.5359 - val_loss: 0.5116
# Epoch 13/600
# 12/12 - 0s - loss: 0.5340 - val_loss: 0.5075
# Epoch 14/600
# 12/12 - 0s - loss: 0.5333 - val_loss: 0.5078
# Epoch 15/600
# 12/12 - 0s - loss: 0.5321 - val_loss: 0.5058
# Epoch 16/600
# 12/12 - 0s - loss: 0.5311 - val_loss: 0.5080
# Epoch 17/600
# 12/12 - 0s - loss: 0.5307 - val_loss: 0.5054
# Epoch 18/600
# 12/12 - 0s - loss: 0.5296 - val_loss: 0.5041
# Epoch 19/600
# 12/12 - 0s - loss: 0.5294 - val_loss: 0.5040
# Epoch 20/600
# 12/12 - 0s - loss: 0.5292 - val_loss: 0.5024
# Epoch 21/600
# 12/12 - 0s - loss: 0.5287 - val_loss: 0.5026
# Epoch 22/600
# 12/12 - 0s - loss: 0.5281 - val_loss: 0.5031
# Epoch 23/600
# 12/12 - 0s - loss: 0.5275 - val_loss: 0.5015
# Epoch 24/600
# 12/12 - 0s - loss: 0.5275 - val_loss: 0.5025
# Epoch 25/600
# 12/12 - 0s - loss: 0.5273 - val_loss: 0.4997
# Epoch 26/600
# 12/12 - 0s - loss: 0.5268 - val_loss: 0.5003
# Epoch 27/600
# 12/12 - 0s - loss: 0.5269 - val_loss: 0.5015
# Epoch 28/600
# 12/12 - 0s - loss: 0.5266 - val_loss: 0.4988
# Epoch 29/600
# 12/12 - 0s - loss: 0.5268 - val_loss: 0.4980
# Epoch 30/600
# 12/12 - 0s - loss: 0.5260 - val_loss: 0.4984
# Epoch 31/600
# 12/12 - 0s - loss: 0.5264 - val_loss: 0.4973
# Epoch 32/600
# 12/12 - 0s - loss: 0.5257 - val_loss: 0.4966
# Epoch 33/600
# 12/12 - 0s - loss: 0.5259 - val_loss: 0.4948
# Epoch 34/600
# 12/12 - 0s - loss: 0.5259 - val_loss: 0.4940
# Epoch 35/600
# 12/12 - 0s - loss: 0.5259 - val_loss: 0.4938
# Epoch 36/600
# 12/12 - 0s - loss: 0.5257 - val_loss: 0.4936
# Epoch 37/600
# 12/12 - 0s - loss: 0.5264 - val_loss: 0.4945
# Epoch 38/600
# 12/12 - 0s - loss: 0.5257 - val_loss: 0.4920
# Epoch 39/600
# 12/12 - 0s - loss: 0.5251 - val_loss: 0.4918
# Epoch 40/600
# 12/12 - 0s - loss: 0.5255 - val_loss: 0.4908
# Epoch 41/600
# 12/12 - 0s - loss: 0.5257 - val_loss: 0.4913
# Epoch 42/600
# 12/12 - 0s - loss: 0.5255 - val_loss: 0.4911
# Epoch 43/600
# 12/12 - 0s - loss: 0.5254 - val_loss: 0.4920
# Epoch 44/600
# 12/12 - 0s - loss: 0.5248 - val_loss: 0.4935
# Epoch 45/600
# 12/12 - 0s - loss: 0.5253 - val_loss: 0.4904
# Epoch 46/600
# 12/12 - 0s - loss: 0.5254 - val_loss: 0.4908
# Epoch 47/600
# 12/12 - 0s - loss: 0.5250 - val_loss: 0.4917
# Epoch 48/600
# 12/12 - 0s - loss: 0.5253 - val_loss: 0.4936
# Epoch 49/600
# 12/12 - 0s - loss: 0.5250 - val_loss: 0.4955
# Epoch 50/600
# 12/12 - 0s - loss: 0.5252 - val_loss: 0.4968
# Epoch 51/600
# 12/12 - 0s - loss: 0.5255 - val_loss: 0.4975
# Epoch 52/600
# 12/12 - 0s - loss: 0.5250 - val_loss: 0.4977
# Epoch 53/600
# 12/12 - 0s - loss: 0.5251 - val_loss: 0.4956
# Epoch 54/600
# 12/12 - 0s - loss: 0.5252 - val_loss: 0.4958
# Epoch 55/600
# 12/12 - 0s - loss: 0.5247 - val_loss: 0.4950
# Epoch 56/600
# 12/12 - 0s - loss: 0.5255 - val_loss: 0.4974
# Epoch 57/600
# 12/12 - 0s - loss: 0.5258 - val_loss: 0.4977
# Epoch 58/600
# 12/12 - 0s - loss: 0.5250 - val_loss: 0.4963
# Epoch 59/600
# 12/12 - 0s - loss: 0.5247 - val_loss: 0.4953
# Epoch 60/600
# 12/12 - 0s - loss: 0.5249 - val_loss: 0.4947
# Epoch 61/600
# 12/12 - 0s - loss: 0.5252 - val_loss: 0.4945
# Epoch 62/600
# 12/12 - 0s - loss: 0.5259 - val_loss: 0.4969
# Epoch 63/600
# 12/12 - 0s - loss: 0.5249 - val_loss: 0.4959
# Epoch 64/600
# 12/12 - 0s - loss: 0.5251 - val_loss: 0.4969
# Epoch 65/600
# 12/12 - 0s - loss: 0.5247 - val_loss: 0.4991
# Epoch 66/600
# 12/12 - 0s - loss: 0.5254 - val_loss: 0.4988
# Epoch 67/600
# 12/12 - 0s - loss: 0.5248 - val_loss: 0.4990
# Epoch 68/600
# 12/12 - 0s - loss: 0.5246 - val_loss: 0.4989
# Epoch 69/600
# 12/12 - 0s - loss: 0.5244 - val_loss: 0.4991
# Epoch 70/600
# 12/12 - 0s - loss: 0.5246 - val_loss: 0.4993
# Epoch 71/600
# 12/12 - 0s - loss: 0.5248 - val_loss: 0.5003
# Epoch 72/600
# 12/12 - 0s - loss: 0.5257 - val_loss: 0.5018
# Epoch 73/600
# 12/12 - 0s - loss: 0.5250 - val_loss: 0.5038
# Epoch 74/600
# 12/12 - 0s - loss: 0.5257 - val_loss: 0.4975
# Epoch 75/600
# 12/12 - 0s - loss: 0.5249 - val_loss: 0.4978
# Epoch 76/600
# 12/12 - 0s - loss: 0.5249 - val_loss: 0.4970
# Epoch 77/600
# 12/12 - 0s - loss: 0.5245 - val_loss: 0.4989
# Epoch 78/600
# 12/12 - 0s - loss: 0.5249 - val_loss: 0.4987
# Epoch 79/600
# 12/12 - 0s - loss: 0.5250 - val_loss: 0.4924
# Epoch 80/600
# 12/12 - 0s - loss: 0.5247 - val_loss: 0.4874
# Epoch 81/600
# 12/12 - 0s - loss: 0.5249 - val_loss: 0.4881
# Epoch 82/600
# 12/12 - 0s - loss: 0.5252 - val_loss: 0.4890
# Epoch 83/600
# 12/12 - 0s - loss: 0.5253 - val_loss: 0.4901
# Epoch 84/600
# 12/12 - 0s - loss: 0.5247 - val_loss: 0.4939
# Epoch 85/600
# 12/12 - 0s - loss: 0.5247 - val_loss: 0.4916
# Epoch 86/600
# 12/12 - 0s - loss: 0.5244 - val_loss: 0.4900
# Epoch 87/600
# 12/12 - 0s - loss: 0.5246 - val_loss: 0.4908
# Epoch 88/600
# 12/12 - 0s - loss: 0.5245 - val_loss: 0.4894
# Epoch 89/600
# 12/12 - 0s - loss: 0.5249 - val_loss: 0.4891
# Epoch 90/600
# 12/12 - 0s - loss: 0.5249 - val_loss: 0.4885
# Epoch 91/600
# 12/12 - 0s - loss: 0.5246 - val_loss: 0.4889
# Epoch 92/600
# 12/12 - 0s - loss: 0.5247 - val_loss: 0.4911
# Epoch 93/600
# 12/12 - 0s - loss: 0.5250 - val_loss: 0.4905
# Epoch 94/600
# 12/12 - 0s - loss: 0.5248 - val_loss: 0.4911
# Epoch 95/600
# 12/12 - 0s - loss: 0.5247 - val_loss: 0.4890
# Epoch 96/600
# 12/12 - 0s - loss: 0.5251 - val_loss: 0.4871
# Epoch 97/600
# 12/12 - 0s - loss: 0.5249 - val_loss: 0.4896
# Epoch 98/600
# 12/12 - 0s - loss: 0.5246 - val_loss: 0.4900
# Epoch 99/600
# 12/12 - 0s - loss: 0.5247 - val_loss: 0.4934
# Epoch 100/600
# 12/12 - 0s - loss: 0.5244 - val_loss: 0.4979
# Epoch 101/600
# 12/12 - 0s - loss: 0.5248 - val_loss: 0.4971
# Epoch 102/600
# 12/12 - 0s - loss: 0.5245 - val_loss: 0.4968
# Epoch 103/600
# 12/12 - 0s - loss: 0.5249 - val_loss: 0.4958
# Epoch 104/600
# 12/12 - 0s - loss: 0.5245 - val_loss: 0.4943
# Epoch 105/600
# 12/12 - 0s - loss: 0.5245 - val_loss: 0.4965
# Epoch 106/600
# 12/12 - 0s - loss: 0.5247 - val_loss: 0.4943
# Epoch 107/600
# 12/12 - 0s - loss: 0.5245 - val_loss: 0.4935
# Epoch 108/600
# 12/12 - 0s - loss: 0.5241 - val_loss: 0.4947
# Epoch 109/600
# 12/12 - 0s - loss: 0.5244 - val_loss: 0.4918
# Epoch 110/600
# 12/12 - 0s - loss: 0.5241 - val_loss: 0.4917
# Epoch 111/600
# 12/12 - 0s - loss: 0.5242 - val_loss: 0.4934
# Epoch 112/600
# 12/12 - 0s - loss: 0.5240 - val_loss: 0.4938
# Epoch 113/600
# 12/12 - 0s - loss: 0.5245 - val_loss: 0.4952
# Epoch 114/600
# 12/12 - 0s - loss: 0.5246 - val_loss: 0.4940
# Epoch 115/600
# 12/12 - 0s - loss: 0.5247 - val_loss: 0.4948
# Epoch 116/600
# 12/12 - 0s - loss: 0.5245 - val_loss: 0.4977
# Epoch 117/600
# 12/12 - 0s - loss: 0.5246 - val_loss: 0.
600
# 12/12 - 0s - loss: 0.5237 - val_loss: 0.4993
# Epoch 476/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.5029
# Epoch 477/600
# 12/12 - 0s - loss: 0.5239 - val_loss: 0.5022
# Epoch 478/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.4994
# Epoch 479/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.5017
# Epoch 480/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.5022
# Epoch 481/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.5024
# Epoch 482/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.5007
# Epoch 483/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4995
# Epoch 484/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.5013
# Epoch 485/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.5005
# Epoch 486/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.5013
# Epoch 487/600
# 12/12 - 0s - loss: 0.5238 - val_loss: 0.5009
# Epoch 488/600
# 12/12 - 0s - loss: 0.5230 - val_loss: 0.4994
# Epoch 489/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.4997
# Epoch 490/600
# 12/12 - 0s - loss: 0.5240 - val_loss: 0.4993
# Epoch 491/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4995
# Epoch 492/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.5024
# Epoch 493/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.5014
# Epoch 494/600
# 12/12 - 0s - loss: 0.5230 - val_loss: 0.5031
# Epoch 495/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.5028
# Epoch 496/600
# 12/12 - 0s - loss: 0.5238 - val_loss: 0.4997
# Epoch 497/600
# 12/12 - 0s - loss: 0.5238 - val_loss: 0.4977
# Epoch 498/600
# 12/12 - 0s - loss: 0.5236 - val_loss: 0.5003
# Epoch 499/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.4988
# Epoch 500/600
# 12/12 - 0s - loss: 0.5238 - val_loss: 0.4979
# Epoch 501/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4979
# Epoch 502/600
# 12/12 - 0s - loss: 0.5238 - val_loss: 0.4973
# Epoch 503/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.4975
# Epoch 504/600
# 12/12 - 0s - loss: 0.5236 - val_loss: 0.4965
# Epoch 505/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.4974
# Epoch 506/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.4978
# Epoch 507/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4961
# Epoch 508/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.4953
# Epoch 509/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4958
# Epoch 510/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.4962
# Epoch 511/600
# 12/12 - 0s - loss: 0.5236 - val_loss: 0.4965
# Epoch 512/600
# 12/12 - 0s - loss: 0.5229 - val_loss: 0.4958
# Epoch 513/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4982
# Epoch 514/600
# 12/12 - 0s - loss: 0.5239 - val_loss: 0.4999
# Epoch 515/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.4985
# Epoch 516/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.5004
# Epoch 517/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.4994
# Epoch 518/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4995
# Epoch 519/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4976
# Epoch 520/600
# 12/12 - 0s - loss: 0.5237 - val_loss: 0.4967
# Epoch 521/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.4987
# Epoch 522/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4963
# Epoch 523/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.4960
# Epoch 524/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.4961
# Epoch 525/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.5001
# Epoch 526/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.4988
# Epoch 527/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.4974
# Epoch 528/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.4975
# Epoch 529/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4964
# Epoch 530/600
# 12/12 - 0s - loss: 0.5236 - val_loss: 0.5011
# Epoch 531/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.5029
# Epoch 532/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.4995
# Epoch 533/600
# 12/12 - 0s - loss: 0.5230 - val_loss: 0.4980
# Epoch 534/600
# 12/12 - 0s - loss: 0.5230 - val_loss: 0.4991
# Epoch 535/600
# 12/12 - 0s - loss: 0.5229 - val_loss: 0.4979
# Epoch 536/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4980
# Epoch 537/600
# 12/12 - 0s - loss: 0.5228 - val_loss: 0.4991
# Epoch 538/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.5004
# Epoch 539/600
# 12/12 - 0s - loss: 0.5230 - val_loss: 0.5019
# Epoch 540/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.5004
# Epoch 541/600
# 12/12 - 0s - loss: 0.5236 - val_loss: 0.5001
# Epoch 542/600
# 12/12 - 0s - loss: 0.5236 - val_loss: 0.5000
# Epoch 543/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.5021
# Epoch 544/600
# 12/12 - 0s - loss: 0.5239 - val_loss: 0.4993
# Epoch 545/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.4981
# Epoch 546/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.4991
# Epoch 547/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4973
# Epoch 548/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4925
# Epoch 549/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.4920
# Epoch 550/600
# 12/12 - 0s - loss: 0.5240 - val_loss: 0.4932
# Epoch 551/600
# 12/12 - 0s - loss: 0.5239 - val_loss: 0.4952
# Epoch 552/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.4923
# Epoch 553/600
# 12/12 - 0s - loss: 0.5240 - val_loss: 0.4933
# Epoch 554/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.4954
# Epoch 555/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4938
# Epoch 556/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4929
# Epoch 557/600
# 12/12 - 0s - loss: 0.5242 - val_loss: 0.4946
# Epoch 558/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4932
# Epoch 559/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.4946
# Epoch 560/600
# 12/12 - 0s - loss: 0.5229 - val_loss: 0.4953
# Epoch 561/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.4943
# Epoch 562/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4950
# Epoch 563/600
# 12/12 - 0s - loss: 0.5229 - val_loss: 0.4945
# Epoch 564/600
# 12/12 - 0s - loss: 0.5229 - val_loss: 0.4947
# Epoch 565/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4940
# Epoch 566/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.4950
# Epoch 567/600
# 12/12 - 0s - loss: 0.5226 - val_loss: 0.4942
# Epoch 568/600
# 12/12 - 0s - loss: 0.5228 - val_loss: 0.4952
# Epoch 569/600
# 12/12 - 0s - loss: 0.5230 - val_loss: 0.4951
# Epoch 570/600
# 12/12 - 0s - loss: 0.5228 - val_loss: 0.4948
# Epoch 571/600
# 12/12 - 0s - loss: 0.5227 - val_loss: 0.4971
# Epoch 572/600
# 12/12 - 0s - loss: 0.5229 - val_loss: 0.4953
# Epoch 573/600
# 12/12 - 0s - loss: 0.5228 - val_loss: 0.4967
# Epoch 574/600
# 12/12 - 0s - loss: 0.5230 - val_loss: 0.4960
# Epoch 575/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4954
# Epoch 576/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4928
# Epoch 577/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.4899
# Epoch 578/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4909
# Epoch 579/600
# 12/12 - 0s - loss: 0.5230 - val_loss: 0.4945
# Epoch 580/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.4940
# Epoch 581/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.4950
# Epoch 582/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4943
# Epoch 583/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4942
# Epoch 584/600
# 12/12 - 0s - loss: 0.5229 - val_loss: 0.4960
# Epoch 585/600
# 12/12 - 0s - loss: 0.5230 - val_loss: 0.4975
# Epoch 586/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4979
# Epoch 587/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4975
# Epoch 588/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4979
# Epoch 589/600
# 12/12 - 0s - loss: 0.5234 - val_loss: 0.4971
# Epoch 590/600
# 12/12 - 0s - loss: 0.5240 - val_loss: 0.4939
# Epoch 591/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4940
# Epoch 592/600
# 12/12 - 0s - loss: 0.5230 - val_loss: 0.4948
# Epoch 593/600
# 12/12 - 0s - loss: 0.5229 - val_loss: 0.4924
# Epoch 594/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.4937
# Epoch 595/600
# 12/12 - 0s - loss: 0.5232 - val_loss: 0.4948
# Epoch 596/600
# 12/12 - 0s - loss: 0.5231 - val_loss: 0.4993
# Epoch 597/600
# 12/12 - 0s - loss: 0.5243 - val_loss: 0.4985
# Epoch 598/600
# 12/12 - 0s - loss: 0.5235 - val_loss: 0.5005
# Epoch 599/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.4983
# Epoch 600/600
# 12/12 - 0s - loss: 0.5233 - val_loss: 0.4975

# %% [markdown]
# <font size=5 color='blue'>
#
# Plots of cost function versus epoch

# %%
plt.figure(figsize=(10, 7))

plt.plot(history.history['loss'], color='red')
plt.plot(history.history['val_loss'], color='green')
plt.title('Cost function', size=16)
plt.ylabel('Cost', size=16)
plt.xlabel('Epoch', size=16)
plt.legend(['cost_train', 'cost_validation'],loc='upper right', prop={'size': 16})
plt.show()

# %% [markdown]
# <font size=5 color='blue'>
#
# Uderfitting

# %% [markdown]
# <font size=5 color='blue'>
#
# ## <center> Learning Machines constructed with Artificial Neural Networks (ANN)</center>

# %% [markdown]
# <font size=5 color='black'>
# <center> SEM images of a neuron and a network of neurons. Neuron model and mathematical model of a neuron </center>

# %% [markdown]
# <table>
#   <tr>
#     <td>Neuron</td>
#      <td>Network of neurons</td>
#       <td>Neuron model</td>
#       <td>Mathematical model of a neuron</td>
#
#   </tr>
#   <tr>
#     <td><img src="neuron_SEM.jpg" width=290 height=480></td>
#     <td><img src="human-neuron.png" width=270 height=480></td>
#     <td><img src="Neuron_labelled.png" width=200 height=380></td>
#     <td><img src="neuron-mat-model.png" width=370 height=380></td>
#   </tr>
#  </table>

# %% [markdown]
# <font size=5 color='black'>
# <center> Approximation by Superpositions of a Sigmoidal Function </center>

# %% [markdown]
# <font size=4 color='black'>
#
# [Reference](./Literatura/Approx-superpositions-sigmoids_1989.pdf)
# $$ $$
# $\bf Abstract$-In this paper we demonstrate that finite linear combinations of com-
# positions of a fixed, univariate function and a set ofaffine functionals can uniformly
# approximate any continuous function of n real variables with support in the unit
# hypercube; only mild conditions are imposed on the univariate function. Our
# results settle an open question about representability in the class of single bidden
# layer neural networks. In particular, we show that arbitrary decision regions can
# be arbitrarily well approximated by continuous feedforward neural networks with
# only a single internal, hidden layer and any continuous sigmoidal nonlinearity. The
# paper discusses approximation properties of other possible types of nonlinearities
# that might be implemented by artificial neural networks.

# %% [markdown]
# <font size=5 color='black'>
# <center> Approximation Capabilities of Multilayer Feedforward Networks </center>

# %% [markdown]
# <font size=4 color='black'>
# $\bf Abstract$--We show that standard multilayer feedfbrward networks with as few as a single hidden layer and
# arbitrary bounded and nonconstant activation function are universal approximators with respect to LP(lt) per-
# formance criteria, for arbitrary finite input environment measures p, provided only that sufficiently many hidden
# units are available. If the activation function is continuous, bounded and nonconstant, then continuous mappings
# can be learned uniformly over compact input sets. We also give very general conditions ensuring that networks
# with sufficiently smooth activation functions are capable of arbitrarily accurate approximation to a_Function and
# its derivatives.
#
# [Reference](./Literatura/FF-NN-universal-Approximator_1991.pdf)

# %% [markdown]
# <font size=5 color='blue'>
#
# ## <center>  A new Learning Machine</center>

# %% [markdown]
# <font size=5 color='blue'>
#
# Model of the Machine: Full-Connected Feed-Forward Network (FF) with one hidden layer with two neurons. The activation function of the last neuron is linear

# %%
n_x = learn_x.shape[1] 
n_h = 2
n_y = learn_y.shape[1]
    
layers = [n_x, n_h, n_y]
net = Network(layers)
net.graph(layers)
# Out:
# It has 3 layers,
# with the following number of nodes per layer [10, 2, 1]

# %% [markdown]
# <font size=5 color='blue'>
#
# Model architecture

# %%
np.random.seed(1)

input_nodes = n_x     # The input layer has n_x nodes
hlayer1_nodes = n_h   # The first hidden layer has n_h nodes
output_nodes = n_y    # The output layer has n_y nodes

model = Sequential()

model.add(Dense(hlayer1_nodes,  kernel_initializer='uniform', bias_initializer='zeros', \
                input_dim=input_nodes, activation='tanh'))

model.add(Dense(output_nodes, kernel_initializer='uniform', bias_initializer='zeros', activation='linear'))

# %% [markdown]
# <font size=5 color='blue'>
# Architecture Summary and Chart

# %%
plot_model(model, to_file='model.png', show_shapes=True, rankdir='TB', 
      expand_nested=True, show_layer_names=True, dpi=96)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 2)                 22
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <font size=5  color='blue'>
#
# Compiling the model. Includes the optimizer definition

# %%
sgd = optimizers.SGD(lr=0.01)

model.compile(loss='mean_squared_error', optimizer=sgd)

# %% [markdown]
# <font size=5 color='blue'>
#
# The Machine is learning

# %%
validation_ratio = 0.1
epochs = 600

history = model.fit(learn_x, learn_y, epochs=epochs, validation_split = validation_ratio, verbose=0)

# %% [markdown]
# <font size=5 color='blue'>
#
# Plots of cost function versus epoch

# %%
plt.figure(figsize=(10, 7))

plt.plot(history.history['loss'], color='red')
plt.plot(history.history['val_loss'], color='green')
plt.title('Cost function', size=16)
plt.ylabel('Cost', size=16)
plt.xlabel('Epoch', size=16)
plt.legend(['cost_train', 'cost_validation'],loc='upper right', prop={'size': 16})
plt.show()

# %% [markdown]
# <font size=5 color='blue'>
#
# A good model

# %% [markdown]
# <font size=5 color='blue'>
#
# ## <center>  A new Learning Machine</center>

# %% [markdown]
# <font size=5 color='blue'>
#
# Model of the Machine: Full-Connected Feed-Forward Network (FF) with one hidden layer with two neurons. The activation function of the last neuron is a sigmoid function.

# %%
n_x = learn_x.shape[1] 
n_h = 2
n_y = learn_y.shape[1]
    
layers = [n_x, n_h, n_y]
net = Network(layers)
net.graph(layers)
# Out:
# It has 3 layers,
# with the following number of nodes per layer [10, 2, 1]

# %% [markdown]
# <font size=5 color='blue'>
#
# Model architecture

# %%
np.random.seed(1)

input_nodes = n_x     # The input layer has n_x nodes
hlayer1_nodes = n_h   # The first hidden layer has n_h nodes
output_nodes = n_y    # The output layer has n_y nodes

model = Sequential()

model.add(Dense(hlayer1_nodes,  kernel_initializer='uniform', bias_initializer='zeros', \
                input_dim=input_nodes, activation='tanh'))

model.add(Dense(output_nodes, kernel_initializer='uniform', bias_initializer='zeros', activation='tanh'))

# %% [markdown]
# <font size=5 color='blue'>
# Architecture Summary and Chart

# %%
plot_model(model, to_file='model.png', show_shapes=True, rankdir='TB', 
      expand_nested=True, show_layer_names=True, dpi=96)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 2)                 22
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <font size=5  color='blue'>
#
# Compiling the model. Includes the optimizer definition

# %%
sgd = optimizers.SGD(lr=0.01)

model.compile(loss='mean_squared_error', optimizer=sgd)

# %% [markdown]
# <font size=5 color='blue'>
#
# The Machine is Learning

# %%
validation_ratio = 0.1
epochs = 600

history = model.fit(learn_x, learn_y, epochs=epochs, validation_split = validation_ratio, verbose=0)

# %% [markdown]
# <font size=5 color='blue'>
#
# Plots of cost function versus epoch

# %%
plt.figure(figsize=(10, 7))

plt.plot(history.history['loss'], color='red')
plt.plot(history.history['val_loss'], color='green')
plt.title('Cost function', size=16)
plt.ylabel('Cost', size=16)
plt.xlabel('Epoch', size=16)
plt.legend(['cost_train', 'cost_validation'],loc='upper right', prop={'size': 16})
plt.show()

# %% [markdown]
# <font size=5 color='blue'>
#
# Overfitting

# %% [markdown]
# <font size=5 color='blue'>
#
# ## <center> A new Learning Machine</center>

# %% [markdown]
# <font size=5 color='blue'>
#
# Model of the Machine: Full-Connected Feed-Forward Network (FF) with one hidden layer with three neurons. The activation function of the last neuron is linear.

# %%
n_x = learn_x.shape[1] 
n_h = 3
n_y = learn_y.shape[1]
    
layers = [n_x, n_h, n_y]
net = Network(layers)
net.graph(layers)
# Out:
# It has 3 layers,
# with the following number of nodes per layer [10, 3, 1]

# %% [markdown]
# <font size=5 color='blue'>
#
# Model architecture

# %%
np.random.seed(1)

model = Sequential()

input_nodes = n_x     #input layer has n_x nodes
hlayer1_nodes = n_h   #first hidden layer has n_h nodes
output_nodes = n_y    #output layer has n_y nodes

model.add(Dense(hlayer1_nodes,  kernel_initializer='uniform', bias_initializer='zeros', \
                input_dim=input_nodes, activation='tanh'))

model.add(Dense(output_nodes, kernel_initializer='uniform', bias_initializer='zeros', activation='linear'))

# %% [markdown]
# <font size=5 color='blue'>
# Architecture Summary and Chart

# %%
plot_model(model, to_file='model.png', show_shapes=True, rankdir='TB', 
      expand_nested=True, show_layer_names=True, dpi=96)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 3)                 33
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 37
# Trainable params: 37
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <font size=5  color='blue'>
#
# Compiling the model. Includes the optimizer definition.

# %%
sgd = optimizers.SGD(lr=0.01)

model.compile(loss='mean_squared_error', optimizer=sgd)

# %% [markdown]
# <font size=5 color='blue'>
#
# The Machine is learning

# %%
validation_ratio = 0.1
epochs = 600

history = model.fit(learn_x, learn_y, epochs=epochs, validation_split = validation_ratio, verbose=0)

# %% [markdown]
# <font size=5 color='blue'>
#
# Plots of cost function versus epoch

# %%
plt.figure(figsize=(10, 7))

plt.plot(history.history['loss'], color='red')
plt.plot(history.history['val_loss'], color='green')
plt.title('Cost function', size=16)
plt.ylabel('Cost', size=16)
plt.xlabel('Epoch', size=16)
plt.legend(['cost_train', 'cost_validation'],loc='upper right', prop={'size': 16})
plt.show()

# %% [markdown]
# <font size=5 color='blue'>
#
# Overfitting

# %% [markdown]
# <font size=5 color='blue'>
#
# ## <center> A new Learning Machine</center>

# %% [markdown]
# <font size=5 color='blue'>
#
# Model of the Machine: Full-Connected Feed-Forward Network (FF) with one hidden layer with four neurons. The activation function of the last neuron is linear.

# %%
n_x = learn_x.shape[1] 
n_h = 4
n_y = learn_y.shape[1]
    
layers = [n_x, n_h, n_y]
net = Network(layers)
net.graph(layers)
# Out:
# It has 3 layers,
# with the following number of nodes per layer [10, 4, 1]

# %% [markdown]
# <font size=5 color='blue'>
#
# Model architecture

# %%
np.random.seed(1)

input_nodes = n_x     # The input layer has n_x nodes
hlayer1_nodes = n_h   # The first hidden layer has n_h nodes
output_nodes = n_y    # The output layer has n_y nodes


model = Sequential()

model.add(Dense(hlayer1_nodes,  kernel_initializer='uniform', bias_initializer='zeros', \
                input_dim=input_nodes, activation='tanh'))

model.add(Dense(output_nodes, kernel_initializer='uniform', bias_initializer='zeros', activation='linear'))

# %% [markdown]
# <font size=5 color='blue'>
# Architecture Summary and Chart

# %%
plot_model(model, to_file='model.png', show_shapes=True, rankdir='TB', 
      expand_nested=True, show_layer_names=True, dpi=96)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 4)                 44
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 49
# Trainable params: 49
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <font size=5  color='blue'>
#
# Compiling the model. Includes the optimizer definition.

# %%
sgd = optimizers.SGD(lr=0.01)

model.compile(loss='mean_squared_error', optimizer=sgd)

# %% [markdown]
# <font size=5 color='blue'>
#
# The Machine is Learning

# %%
validation_ratio = 0.1
epochs = 600

history = model.fit(learn_x, learn_y, epochs=epochs, validation_split = validation_ratio,verbose=0)

# %% [markdown]
# <font size=5 color='blue'>
#
# Plots of cost function versus epoch

# %%
plt.figure(figsize=(10, 7))

plt.plot(history.history['loss'], color='red')
plt.plot(history.history['val_loss'], color='green')
plt.title('Cost function', size=16)
plt.ylabel('Cost', size=16)
plt.xlabel('Epoch', size=16)
plt.legend(['cost_train', 'cost_validation'],loc='upper right', prop={'size': 16})
plt.show()

# %% [markdown]
# <font size=5 color='blue'>
#
# Overfitting

# %% [markdown]
# <font size=5 color='blue'>
#
# ## <center> A new Learning Machine</center>

# %% [markdown]
# <font size=5 color='blue'>
#
# Model of the Machine: A Full-Connected Feed-Forward Network (FF) with two hidden layers: the first of which has 5 neurons and the second is one that has 4 neurons. The activation function of the last neuron is linear.

# %%
n_x = learn_x.shape[1] 
n_h1 = 5
n_h2  = 4
n_y = learn_y.shape[1]
    
layers = [n_x, n_h1, n_h2, n_y]
net = Network(layers)
net.graph(layers)
# Out:
# It has 4 layers,
# with the following number of nodes per layer [10, 5, 4, 1]

# %% [markdown]
# <font size=5 color='blue'>
#
# Model architecture

# %%
np.random.seed(1)

input_nodes = n_x     # The input layer has n_x nodes
hlayer1_nodes = n_h1  # The first hidden layer has n_h1 nodes
hlayer2_nodes = n_h2  # The second hidden layes has n_h2 nodes
output_nodes = n_y    # The output layer has n_y nodes


model = Sequential()

model.add(Dense(hlayer1_nodes,  kernel_initializer='uniform', bias_initializer='zeros', \
                input_dim=input_nodes, activation='tanh'))

model.add(Dense(hlayer2_nodes,  kernel_initializer='uniform', bias_initializer='zeros', \
                input_dim=input_nodes, activation='tanh'))


model.add(Dense(output_nodes, kernel_initializer='uniform', bias_initializer='zeros', activation='linear'))

# %% [markdown]
# <font size=5 color='blue'>
# Architecture Summary and Chart

# %%
plot_model(model, to_file='model.png', show_shapes=True, rankdir='TB', 
      expand_nested=True, show_layer_names=True, dpi=96)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 5)                 55
# _________________________________________________________________
# dense_11 (Dense)             (None, 4)                 24
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 84
# Trainable params: 84
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <font size=5  color='blue'>
#
# Compiling the model. Includes the optimizer definition.

# %%
sgd = optimizers.SGD(lr=0.01)

model.compile(loss='mean_squared_error', optimizer=sgd)

# %% [markdown]
# <font size=5 color='blue'>
#
# The Machine is learning

# %%
validation_ratio = 0.1
epochs = 600

history = model.fit(learn_x, learn_y, epochs=epochs, validation_split = validation_ratio,verbose=0)

# %% [markdown]
# <font size=5 color='blue'>
#
# Plots of cost function versus epoch

# %%
plt.figure(figsize=(10, 7))

plt.plot(history.history['loss'], color='red')
plt.plot(history.history['val_loss'], color='green')
plt.title('Cost function', size=16)
plt.ylabel('Cost', size=16)
plt.xlabel('Epoch', size=16)
plt.legend(['cost_train', 'cost_validation'],loc='upper right', prop={'size': 16})
plt.show()

# %% [markdown]
# <font size=5 color='blue'>
#
# Overfitting
